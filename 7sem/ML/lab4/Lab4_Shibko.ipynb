# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2ed86ace-c608-4767-9e2d-132317e73871" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2ed86ace-c608-4767-9e2d-132317e73871">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Вывод первых строк, чтобы убедиться в правильности загрузки
df.head()
# Out:
#    Unnamed: 0              State  Year  Rape   K&A   DD   AoW   AoM    DV  WT
# 0           0     ANDHRA PRADESH  2001   871   765  420  3544  2271  5791   7
# 1           1  ARUNACHAL PRADESH  2001    33    55    0    78     3    11   0
# 2           2              ASSAM  2001   817  1070   59   850     4  1248   0
# 3           3              BIHAR  2001   888   518  859   562    21  1558  83
# 4           4       CHHATTISGARH  2001   959   171   70  1763   161   840   0

# %%
# Проверка наличия колонок
print("Columns in the dataset:")
print(df.columns)
# Out:
# Columns in the dataset:
# Index(['State', 'Year', 'Rape', 'K&A', 'DD', 'AoW', 'AoM', 'DV', 'WT'], dtype='object')

# %%
# Проверьте, что данные были успешно загружены
if 'data' in locals():
    # Шаг 2: Предобработка данных
    # Преобразование категориальных данных 'State' с помощью LabelEncoder
    label_encoder = LabelEncoder()
    data['State'] = label_encoder.fit_transform(data['State'])

    # Выбор целевой переменной (например, 'Rape') и признаков
    X = data.drop(columns=['Rape'])  # Признаки
    y = data['Rape']  # Целевая переменная

    # Масштабирование данных
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # Разделение на обучающую и тестовую выборки
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Шаг 3: Обучение моделей
# Логистическая регрессия
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
y_pred_log_reg = log_reg.predict(X_test)

# Дерево решений
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
y_pred_tree = tree.predict(X_test)

# Случайный лес
forest = RandomForestClassifier()
forest.fit(X_train, y_train)
y_pred_forest = forest.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Шаг 4: Оценка моделей
print("Логистическая регрессия:")
print(classification_report(y_test, y_pred_log_reg))
print("Точность логистической регрессии:", accuracy_score(y_test, y_pred_log_reg))

print("\nДерево решений:")
print(classification_report(y_test, y_pred_tree))
print("Точность дерева решений:", accuracy_score(y_test, y_pred_tree))

print("\nСлучайный лес:")
print(classification_report(y_test, y_pred_forest))
print("Точность случайного леса:", accuracy_score(y_test, y_pred_forest))
# Out:
# Логистическая регрессия:
#               precision    recall  f1-score   support
#
#            0       1.00      0.25      0.40         4
#            1       0.00      0.00      0.00         4
#            2       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         2
#            5       0.00      0.00      0.00         2
#            6       0.00      0.00      0.00         2
#            7       0.00      0.00      0.00         2
#            9       0.00      0.00      0.00         1
#           10       0.00      0.00      0.00         2
#           12       0.00      0.00      0.00         3
#           13       0.00      0.00      0.00         2
#           14       0.00      0.00      0.00         2
#           16       0.00      0.00      0.00         1
#           18       0.00      0.00      0.00         5
#           19       0.00      0.00      0.00         2
#           20       0.00      0.00      0.00         1
# ...

# %%
# Выбор модели с наилучшей точностью
best_model = max([
    ('Logistic Regression', accuracy_score(y_test, y_pred_log_reg)),
    ('Decision Tree', accuracy_score(y_test, y_pred_tree)),
    ('Random Forest', accuracy_score(y_test, y_pred_forest))
], key=lambda x: x[1])

print(f"\nЛучшая модель: {best_model[0]} с точностью {best_model[1]}")
# Out:
# Лучшая модель: Decision Tree с точностью 0.04054054054054054
